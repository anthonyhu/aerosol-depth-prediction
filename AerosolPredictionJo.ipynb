# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.metrics import mean_squared_error
import xgboost as xgb
from hyperopt import STATUS_OK, hp, fmin, tpe, Trials, space_eval

from time import time
import operator

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import itertools
import tensorflow as tf

tf.logging.set_verbosity(tf.logging.INFO)

# %% [markdown]
# ### Start training

# %%
# Import data
def load_data():
    full_data = pd.read_csv("X.csv")
    train_y = pd.read_csv("ytr.csv")
    # Rename columns to something more interpretable
    columns = (["reflectance_" + str(i) for i in range(7)]
               + ["solar_" + str(i) for i in range(5)] + ["id"])
    full_data.columns = columns
    # Add y to the data frame
    split = 98000
    y_id_dict = train_y.set_index("Id")["y"].to_dict()
    full_data.loc[:(split-1), "y"] = full_data.loc[:(split-1), "id"].replace(y_id_dict)

    train, test = full_data[:split], full_data[split:]
    return (train, test)

#columns = (["id"] + ["reflectance_" + str(i) for i in range(7)]
#           + ["solar_" + str(i) for i in range(5)] + ["y"])
#full_data = pd.read_csv("MODIS.csv", header=None, names=columns)
#split = 98000
#train, test = full_data[:split].copy(), full_data[split:].copy()
train, test = load_data()

# Parameters
outliers_threshold = 0.05
n_threads = -1
random_seed = 22

# %%
train.head()
# Out:
#    reflectance_0  reflectance_1  reflectance_2  reflectance_3  reflectance_4  \
# 0       1.580642       2.482233       5.887092       4.732722       4.408482
# 1       2.338455       3.627796       4.723716       3.324726       2.743442
# 2       2.224569       3.522241       6.188831       4.389783       4.177616
# 3       1.717218       2.712012       5.024211       3.944907       3.393424
# 4       2.378857       3.644976       4.515292       3.223825       2.739952
#
#    reflectance_5  reflectance_6    solar_0   solar_1   solar_2   solar_3  \
# 0       3.830171       4.388508  22.572888  63.58724  88.05048  4.495216
# 1       4.727652       2.810193  22.572888  63.58724  88.05048  4.495216
# 2       4.945918       4.122848  22.572888  63.58724  88.05048  4.495216
# 3       3.931973       3.489578  22.572888  63.58724  88.05048  4.495216
# 4       4.599662       2.781574  22.572888  63.58724  88.05048  4.495216
#
#      solar_4  id         y
# 0 -50.699904   1 -3.998082
# 1 -50.699904   1 -3.998082
# 2 -50.699904   1 -3.998082
# 3 -50.699904   1 -3.998082
# 4 -50.699904   1 -3.998082

# %% [markdown]
# ### Preprocessing

# %%
cols_excl = ["id", "y"]
cols_orig = [c for c in train.columns if c not in cols_excl]

# %% [markdown]
# ### Cross-validation

# %%
## Gradient boosting
cols_dnn = cols_orig

models_weights = {"dnn": 1.0}
models_cols = {"dnn": cols_dnn}
tf.logging.set_verbosity(tf.logging.ERROR)

# Scoring function in the hyperopt hyperparameters tuning.
def scoring_function(parameters):
    print("Training the model with parameters: ")
    print(parameters)
    average_RMSE = 0.0
    n_splits = 5

    kf = KFold(n_splits=n_splits)
    for train_index, validation_index in kf.split(train):
        train_fold, validation_fold = train.loc[train_index], train.loc[validation_index] 

        #model_lr0 = LinearRegression()
        #model_lr0.fit(train_fold[cols_lr0], train_fold["y"])
        feature_cols = [tf.contrib.layers.real_valued_column(k) for k in cols_dnn]
        
        # Tune number of layers
        model_dir = ("./temp_log_"
                     + str(parameters["steps"]) + "_"
                     + str(parameters["nb_neurons_1"]) #+ "_"
                     #+ str(parameters["nb_neurons_2"])
                    )
        model_dnn = tf.contrib.learn.DNNRegressor(feature_columns=feature_cols,
                                                  hidden_units=[parameters["nb_neurons_1"]],
                                                                #parameters["nb_neurons_2"]],
                                                  #optimizer=tf.train.ProximalAdagradOptimizer(
                                                   #   learning_rate=0.1,
                                                    #  l1_regularization_strength=0.001),
                                                  model_dir=model_dir)

        def input_fn(data_set):
            feature_cols = {k: tf.constant(data_set[k].values) for k in cols_dnn}
            labels = tf.constant(data_set["y"].values)
            return feature_cols, labels

        model_dnn.fit(input_fn=lambda: input_fn(train_fold), steps=parameters["steps"])
        
        models = {"dnn": model_dnn}

        train_pred = train_fold[["id"]].assign(y_hat=0)
        for i, m in models.items():
            temp = m.predict(input_fn=lambda: input_fn(train_fold))
            # .predict() returns an iterator; convert to an array
            y_hat = np.array(list(itertools.islice(temp, 0, None)))
            train_pred["y_hat"] += models_weights[i] * y_hat

        # Use median value by id
        y_hat_med = train_pred.groupby("id").median()["y_hat"].to_dict()

        RMSE = np.sqrt(mean_squared_error(train_pred["id"].replace(y_hat_med).values, train_fold["y"]))
        
        # Prune outliers
        RMSE_decreasing = True
        count = 0
        while (RMSE_decreasing):
            count +=1
            if ((count % 2) == 0):
                print(count)
            train_pred["y_med"] = train_pred["id"].replace(y_hat_med)

            # Distance from the median for each bag
            train_pred["score"] = (train_pred["y_hat"] - train_pred["y_med"])**2
            # Rank of each instance by bag
            train_pred["rank"] = train_pred.groupby("id")["score"].rank()
            bag_size_dict = train_pred.groupby("id")["score"].count().to_dict()
            train_pred["bag_size"] = train_pred["id"].replace(bag_size_dict)
            train_pred["rank"] = train_pred["rank"] / train_pred["bag_size"]

            # Remove outliers
            outliers_index = train_pred["rank"] > (1 - outliers_threshold)
            train_fold = train_fold.loc[~outliers_index, :].reset_index(drop=True)

            #model_lr0 = LinearRegression()
            #model_lr0.fit(train_fold[cols_lr0], train_fold["y"])
            model_dnn = tf.contrib.learn.DNNRegressor(feature_columns=feature_cols,
                                                      hidden_units=[parameters["nb_neurons_1"]],
                                                                    #parameters["nb_neurons_2"]],
                                                      #optimizer=tf.train.ProximalAdagradOptimizer(
                                                       #   learning_rate=0.1,
                                                        #  l1_regularization_strength=0.001),
                                                      model_dir=model_dir)

            model_dnn.fit(input_fn=lambda: input_fn(train_fold), steps=parameters["steps"])

            models = {"dnn": model_dnn}

            # Compute new RMSE
            train_pred = train_fold[["id"]].assign(y_hat=0)
            
            for i, m in models.items():
                temp = m.predict(input_fn=lambda: input_fn(train_fold))
                # .predict() returns an iterator; convert to an array
                y_hat = np.array(list(itertools.islice(temp, 0, None)))
                train_pred["y_hat"] += models_weights[i] * y_hat

            # Use median value by id
            y_hat_med = train_pred.groupby("id").median()["y_hat"].to_dict()

            new_RMSE = np.sqrt(mean_squared_error(train_pred["id"].replace(y_hat_med), train_fold["y"]))
            if ((count % 2) == 0):
                print(new_RMSE)

            if (new_RMSE < RMSE):
                RMSE = new_RMSE
            else:
                RMSE_decreasing = False

        # Compute RMSE on validation set
        validation_pred = validation_fold[["id"]].assign(y_hat=0).reset_index(drop=True)
        for i, m in models.items():
            if (i == "dnn"):
                temp = m.predict(input_fn=lambda: input_fn(validation_fold))
                # .predict() returns an iterator; convert to an array
                y_hat = np.array(list(itertools.islice(temp, 0, None)))
                validation_pred["y_hat"] += models_weights[i] * y_hat
            else:
                validation_pred["y_hat"] += models_weights[i] * m.predict(validation_fold[models_cols[i]])
            
        # Use median value by id
        y_hat_med = validation_pred.groupby("id").median()["y_hat"].to_dict()
        
        RMSE = np.sqrt(mean_squared_error(validation_pred["id"].replace(y_hat_med).values, validation_fold["y"]))
        average_RMSE += RMSE
        print("Current validation RMSE: {0}".format(RMSE))

    average_RMSE /= n_splits

    print("Cross-validation score: {0}\n".format(average_RMSE))
    
    return {"loss": average_RMSE, "status": STATUS_OK}

# %%
t0 = time()

# Grid to pick parameters from.
parameters_grid = {#"eta"              : hp.quniform("eta", 0.1, 0.3, 0.1),
                   #"max_depth"        : hp.choice("max_depth", np.arange(4, 5, dtype=int)),
                   #"min_child_weight": hp.quniform("min_child_weight", 10, 15, 1),
                   "steps": hp.choice("steps", np.arange(500, 1000, 100, dtype=int)),
                   "nb_neurons_1": hp.choice("nb_neurons_1", np.arange(9, 11, 1, dtype=int))
                   #"nb_neurons_2": hp.choice("nb_neurons_2", np.arange(5, 10, 1, dtype=int))
                  }
# Record the information about the cross-validation.
trials = Trials()

best = fmin(scoring_function, parameters_grid, algo=tpe.suggest, max_evals=5, 
            trials=trials) 

computing_time = time() - t0
# Out:
# Training the model with parameters:
# {'nb_neurons_1': 9, 'steps': 500}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-b4ef2bbd0efe> in <module>()
#      13
#      14 best = fmin(scoring_function, parameters_grid, algo=tpe.suggest, max_evals=5,
# ---> 15             trials=trials)
#      16
#      17 computing_time = time() - t0
#
# C:\ProgramData\Anaconda3\lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin)
#     305             verbose=verbose,
#     306             catch_eval_exceptions=catch_eval_exceptions,
# --> 307             return_argmin=return_argmin,
#     308         )
#     309
#
# C:\ProgramData\Anaconda3\lib\site-packages\hyperopt\base.py in fmin(self, fn, space, algo, max_evals, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin)
#     633             pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     634             catch_eval_exceptions=catch_eval_exceptions,
# --> 635             return_argmin=return_argmin)
#     636
#     637
#
# C:\ProgramData\Anaconda3\lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin)
#     318                     verbose=verbose)
#     319     rval.catch_eval_exceptions = catch_eval_exceptions
# --> 320     rval.exhaust()
#     321     if return_argmin:
#     322         return trials.argmin
#
# C:\ProgramData\Anaconda3\lib\site-packages\hyperopt\fmin.py in exhaust(self)
#     197     def exhaust(self):
#     198         n_done = len(self.trials)
# --> 199         self.run(self.max_evals - n_done, block_until_done=self.async)
#     200         self.trials.refresh()
#     201         return self
#
# C:\ProgramData\Anaconda3\lib\site-packages\hyperopt\fmin.py in run(self, N, block_until_done)
#     171             else:
#     172                 # -- loop over trials and do the jobs directly
# --> 173                 self.serial_evaluate()
#     174
#     175             if stopped:
#
# C:\ProgramData\Anaconda3\lib\site-packages\hyperopt\fmin.py in serial_evaluate(self, N)
#      90                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#      91                 try:
# ---> 92                     result = self.domain.evaluate(spec, ctrl)
#      93                 except Exception as e:
#      94                     logger.info('job exception: %s' % str(e))
#
# C:\ProgramData\Anaconda3\lib\site-packages\hyperopt\base.py in evaluate(self, config, ctrl, attach_attachments)
#     838                 memo=memo,
#     839                 print_node_on_error=self.rec_eval_print_node_on_error)
# --> 840             rval = self.fn(pyll_rval)
#     841
#     842         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-7-950b01608d7d> in scoring_function(parameters)
#      40             return feature_cols, labels
#      41
# ---> 42         model_dnn.fit(input_fn=lambda: input_fn(train_fold), steps=parameters["steps"])
#      43
#      44         models = {"dnn": model_dnn}
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     278             _call_location(), decorator_utils.get_qualified_name(func),
#     279             func.__module__, arg_name, date, instructions)
# --> 280       return func(*args, **kwargs)
#     281     new_func.__doc__ = _add_deprecated_arg_notice_to_docstring(
#     282         func.__doc__, date, instructions)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\estimator.py in fit(self, x, y, input_fn, steps, batch_size, monitors, max_steps)
#     424       hooks.append(basic_session_run_hooks.StopAtStepHook(steps, max_steps))
#     425
# --> 426     loss = self._train_model(input_fn=input_fn, hooks=hooks)
#     427     logging.info('Loss for final step: %s.', loss)
#     428     return self
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\estimator.py in _train_model(self, input_fn, hooks)
#     932       features, labels = input_fn()
#     933       self._check_inputs(features, labels)
# --> 934       model_fn_ops = self._call_legacy_get_train_ops(features, labels)
#     935       ops.add_to_collection(ops.GraphKeys.LOSSES, model_fn_ops.loss)
#     936       all_hooks.extend([
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\estimator.py in _call_legacy_get_train_ops(self, features, labels)
#    1001
#    1002   def _call_legacy_get_train_ops(self, features, labels):
# -> 1003     train_ops = self._get_train_ops(features, labels)
#    1004     if isinstance(train_ops, model_fn_lib.ModelFnOps):  # Default signature
#    1005       return train_ops
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\estimator.py in _get_train_ops(self, features, labels)
#    1160       `ModelFnOps` object.
#    1161     """
# -> 1162     return self._call_model_fn(features, labels, model_fn_lib.ModeKeys.TRAIN)
#    1163
#    1164   def _get_eval_ops(self, features, labels, metrics):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\estimator.py in _call_model_fn(self, features, labels, mode)
#    1131     if 'model_dir' in model_fn_args:
#    1132       kwargs['model_dir'] = self.model_dir
# -> 1133     model_fn_results = self._model_fn(features, labels, **kwargs)
#    1134
#    1135     if isinstance(model_fn_results, model_fn_lib.ModelFnOps):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\dnn.py in _dnn_model_fn(features, labels, mode, params, config)
#     141           activation_fn=activation_fn,
#     142           variables_collections=[parent_scope],
# --> 143           scope=scope)
#     144       if dropout is not None and mode == model_fn.ModeKeys.TRAIN:
#     145         net = layers.dropout(net, keep_prob=(1.0 - dropout))
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\framework\python\ops\arg_scope.py in func_with_args(*args, **kwargs)
#     175       current_args = current_scope[key_func].copy()
#     176       current_args.update(kwargs)
# --> 177     return func(*args, **current_args)
#     178   _add_op(func)
#     179   setattr(func_with_args, '_key_op', _key_op(func))
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\layers\python\layers\layers.py in fully_connected(inputs, num_outputs, activation_fn, normalizer_fn, normalizer_params, weights_initializer, weights_regularizer, biases_initializer, biases_regularizer, reuse, variables_collections, outputs_collections, trainable, scope)
#    1384   """
#    1385   if not isinstance(num_outputs, six.integer_types):
# -> 1386     raise ValueError('num_outputs should be int or long, got %s.', num_outputs)
#    1387
#    1388   layer_variable_getter = _build_variable_getter({'bias': 'biases',
#
# ValueError: ('num_outputs should be int or long, got %s.', 9)

# %%
0.818739649008
0.770475036604
0.771639976693
0.718388782706
0.817479974058
Cross-validation score: 0.779344683814

# %%
min(trials.losses())
# Out:
# 0.7793446838139222

# %%
# Save the best parameters as a csv.
best_parameters = pd.DataFrame({key: [value] for (key, value) in 
                                zip(space_eval(parameters_grid, best).keys(),
                                    space_eval(parameters_grid, best).values())})
# Add the corresponding score.
best_parameters["score"] = min(trials.losses())
best_parameters.to_csv("best_parameters_2.csv", encoding="utf-8", index=False)

best_parameters
# Out:
#    eta eval_metric  lambda  max_depth  nthread   objective  seed  silent  \
# 0  0.4        rmse     0.4          4       -1  reg:linear    22       0
#
#    subsample     score
# 0        0.9  0.779345

# %% [markdown]
# ### Training models

# %% [markdown]
# ### Predicting

# %%
kaggle_pred = pd.DataFrame({"Id": y_hat_med.index, "y": y_hat_med.values})
kaggle_pred.to_csv("Prediction_2.csv", encoding="utf-8", index=False)

# %% [markdown]
# ### Benchmark:
# Submit 1 (ensemble of xgboost + 2 ridge with instances model)
# eta	eval_metric	gamma	lambda	max_depth	min_child_weight	nthread	objective	seed	silent	subsample	score
# 0.91834 Public LB 300 trees 0.09	rmse	0.2	0.8	4	4.0	-1	reg:linear	22	0	0.7	0.883339 (cross-val)
#
# Submit 2
#
# Pruning with linear regression
# then add contributions of aggregated xgboost + linear model
# 0.78181 Public LB  0.779345 CV

# %%
tf.logging.set_verbosity(tf.logging.DEBUG)
average_RMSE = 0.0
n_splits = 5
steps = 900
nb_neurons_1 = 9

kf = KFold(n_splits=n_splits)
for train_index, validation_index in kf.split(train):
    train_fold, validation_fold = train.loc[train_index], train.loc[validation_index] 

    #model_lr0 = LinearRegression()
    #model_lr0.fit(train_fold[cols_lr0], train_fold["y"])
    feature_cols = [tf.contrib.layers.real_valued_column(k) for k in cols_dnn]

    # Tune number of layers
    model_dir = ("./temp_log_"
                 + str(steps) + "_"
                 + str(nb_neurons_1) #+ "_"
                 #+ str(parameters["nb_neurons_2"])
                )
    
    validation_monitor = tf.contrib.learn.monitors.ValidationMonitor(
        input_fn=lambda: input_fn(train_fold),
        early_stopping_metric="loss",
        early_stopping_metric_minimize=True,
        early_stopping_rounds=200)

    model_dnn = tf.contrib.learn.DNNRegressor(feature_columns=feature_cols,
                                              hidden_units=[nb_neurons_1],
                                                            #parameters["nb_neurons_2"]],
                                              #optimizer=tf.train.ProximalAdagradOptimizer(
                                               #   learning_rate=0.1,
                                                #  l1_regularization_strength=0.001),
                                              model_dir=model_dir)

    def input_fn(data_set):
        feature_cols = {k: tf.constant(data_set[k].values) for k in cols_dnn}
        labels = tf.constant(data_set["y"].values)
        return feature_cols, labels

    model_dnn.fit(input_fn=lambda: input_fn(train_fold), steps=steps)

    models = {"dnn": model_dnn}

    train_pred = train_fold[["id"]].assign(y_hat=0)
    for i, m in models.items():
        temp = m.predict(input_fn=lambda: input_fn(train_fold))
        # .predict() returns an iterator; convert to an array
        y_hat = np.array(list(itertools.islice(temp, 0, None)))
        train_pred["y_hat"] += models_weights[i] * y_hat

    # Use median value by id
    y_hat_med = train_pred.groupby("id").median()["y_hat"].to_dict()

    RMSE = np.sqrt(mean_squared_error(train_pred["id"].replace(y_hat_med).values, train_fold["y"]))

    # Prune outliers
    RMSE_decreasing = True
    count = 0
    while (RMSE_decreasing):
        count +=1
        if ((count % 2) == 0):
            print(count)
        train_pred["y_med"] = train_pred["id"].replace(y_hat_med)

        # Distance from the median for each bag
        train_pred["score"] = (train_pred["y_hat"] - train_pred["y_med"])**2
        # Rank of each instance by bag
        train_pred["rank"] = train_pred.groupby("id")["score"].rank()
        bag_size_dict = train_pred.groupby("id")["score"].count().to_dict()
        train_pred["bag_size"] = train_pred["id"].replace(bag_size_dict)
        train_pred["rank"] = train_pred["rank"] / train_pred["bag_size"]

        # Remove outliers
        outliers_index = train_pred["rank"] > (1 - outliers_threshold)
        train_fold = train_fold.loc[~outliers_index, :].reset_index(drop=True)
        
        validation_monitor = tf.contrib.learn.monitors.ValidationMonitor(
        input_fn=lambda: input_fn(train_fold),
        early_stopping_metric="loss",
        early_stopping_metric_minimize=True,
        early_stopping_rounds=200)

        #model_lr0 = LinearRegression()
        #model_lr0.fit(train_fold[cols_lr0], train_fold["y"])
        model_dnn = tf.contrib.learn.DNNRegressor(feature_columns=feature_cols,
                                                  hidden_units=[nb_neurons_1],
                                                                #parameters["nb_neurons_2"]],
                                                  #optimizer=tf.train.ProximalAdagradOptimizer(
                                                   #   learning_rate=0.1,
                                                    #  l1_regularization_strength=0.001),
                                                  model_dir=model_dir)

        model_dnn.fit(input_fn=lambda: input_fn(train_fold), steps=steps)

        models = {"dnn": model_dnn}

        # Compute new RMSE
        train_pred = train_fold[["id"]].assign(y_hat=0)

        for i, m in models.items():
            temp = m.predict(input_fn=lambda: input_fn(train_fold))
            # .predict() returns an iterator; convert to an array
            y_hat = np.array(list(itertools.islice(temp, 0, None)))
            train_pred["y_hat"] += models_weights[i] * y_hat

        # Use median value by id
        y_hat_med = train_pred.groupby("id").median()["y_hat"].to_dict()

        new_RMSE = np.sqrt(mean_squared_error(train_pred["id"].replace(y_hat_med), train_fold["y"]))
        if ((count % 2) == 0):
            print(new_RMSE)

        if (new_RMSE < RMSE):
            RMSE = new_RMSE
        else:
            RMSE_decreasing = False

    # Compute RMSE on validation set
    validation_pred = validation_fold[["id"]].assign(y_hat=0).reset_index(drop=True)
    for i, m in models.items():
        if (i == "dnn"):
            temp = m.predict(input_fn=lambda: input_fn(validation_fold))
            # .predict() returns an iterator; convert to an array
            y_hat = np.array(list(itertools.islice(temp, 0, None)))
            validation_pred["y_hat"] += models_weights[i] * y_hat
        else:
            validation_pred["y_hat"] += models_weights[i] * m.predict(validation_fold[models_cols[i]])

    # Use median value by id
    y_hat_med = validation_pred.groupby("id").median()["y_hat"].to_dict()

    RMSE = np.sqrt(mean_squared_error(validation_pred["id"].replace(y_hat_med).values, validation_fold["y"]))
    average_RMSE += RMSE
    print("Current validation RMSE: {0}".format(RMSE))

average_RMSE /= n_splits

print("Cross-validation score: {0}\n".format(average_RMSE))
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:322: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_summary_steps': 100, '_task_id': 0, '_master': '', '_keep_checkpoint_every_n_hours': 10000, '_keep_checkpoint_max': 5, '_tf_random_seed': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_task_type': None, '_is_chief': True, '_environment': 'local', '_num_ps_replicas': 0, '_evaluation_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000021664DC4C50>, '_save_checkpoints_secs': 600, '_save_checkpoints_steps': None}
# DEBUG:tensorflow:Setting feature info to {'reflectance_6': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(78400)]), is_sparse=False), 'solar_1': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(78400)]), is_sparse=False), 'reflectance_2': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(78400)]), is_sparse=False), 'solar_0': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(78400)]), is_sparse=False), 'reflectance_4': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(78400)]), is_sparse=False), 'reflectance_3': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(78400)]), is_sparse=False), 'reflectance_1': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(78400)]), is_sparse=False), 'solar_2': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(78400)]), is_sparse=False), 'solar_4': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(78400)]), is_sparse=False), 'reflectance_0': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(78400)]), is_sparse=False), 'solar_3': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(78400)]), is_sparse=False), 'reflectance_5': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(78400)]), is_sparse=False)}.
# DEBUG:tensorflow:Setting labels info to TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(78400)]), is_sparse=False)
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_0', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_1', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_2', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_3', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_4', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_5', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_6', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_0', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_1', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_2', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_3', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_4', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 74701 into ./temp_log_900_9\model.ckpt.
# INFO:tensorflow:step = 74701, loss = 1.19787
# INFO:tensorflow:global_step/sec: 33.0507
# INFO:tensorflow:step = 74801, loss = 1.06725
# INFO:tensorflow:global_step/sec: 34.6118
# INFO:tensorflow:step = 74901, loss = 1.00711
# INFO:tensorflow:global_step/sec: 34.7652
# INFO:tensorflow:step = 75001, loss = 0.963479
# INFO:tensorflow:global_step/sec: 35.2309
# INFO:tensorflow:step = 75101, loss = 0.930862
# INFO:tensorflow:global_step/sec: 35.385
# INFO:tensorflow:step = 75201, loss = 0.90618
# INFO:tensorflow:global_step/sec: 35.3182
# INFO:tensorflow:step = 75301, loss = 0.887325
# INFO:tensorflow:global_step/sec: 33.9357
# INFO:tensorflow:step = 75401, loss = 0.872816
# INFO:tensorflow:global_step/sec: 33.8432
# INFO:tensorflow:step = 75501, loss = 0.861568
# INFO:tensorflow:Saving checkpoints for 75600 into ./temp_log_900_9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.852862.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_0', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_1', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_2', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_3', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_4', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_5', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_6', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_0', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_1', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_2', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_3', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_4', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:322: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_summary_steps': 100, '_task_id': 0, '_master': '', '_keep_checkpoint_every_n_hours': 10000, '_keep_checkpoint_max': 5, '_tf_random_seed': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_task_type': None, '_is_chief': True, '_environment': 'local', '_num_ps_replicas': 0, '_evaluation_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000002166521C7F0>, '_save_checkpoints_secs': 600, '_save_checkpoints_steps': None}
# DEBUG:tensorflow:Setting feature info to {'reflectance_6': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(74480)]), is_sparse=False), 'solar_1': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(74480)]), is_sparse=False), 'reflectance_2': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(74480)]), is_sparse=False), 'solar_0': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(74480)]), is_sparse=False), 'reflectance_4': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(74480)]), is_sparse=False), 'reflectance_3': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(74480)]), is_sparse=False), 'reflectance_1': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(74480)]), is_sparse=False), 'solar_2': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(74480)]), is_sparse=False), 'solar_4': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(74480)]), is_sparse=False), 'reflectance_0': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(74480)]), is_sparse=False), 'solar_3': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(74480)]), is_sparse=False), 'reflectance_5': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(74480)]), is_sparse=False)}.
# DEBUG:tensorflow:Setting labels info to TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(74480)]), is_sparse=False)
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_0', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_1', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_2', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_3', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_4', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_5', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_6', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_0', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_1', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_2', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_3', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_4', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 75601 into ./temp_log_900_9\model.ckpt.
# INFO:tensorflow:step = 75601, loss = 0.757336
# INFO:tensorflow:global_step/sec: 33.9092
# INFO:tensorflow:step = 75701, loss = 0.75295
# INFO:tensorflow:global_step/sec: 37.2811
# INFO:tensorflow:step = 75801, loss = 0.752163
# INFO:tensorflow:global_step/sec: 41.6672
# INFO:tensorflow:step = 75901, loss = 0.751623
# INFO:tensorflow:global_step/sec: 36.9023
# INFO:tensorflow:step = 76001, loss = 0.751157
# INFO:tensorflow:global_step/sec: 35.8016
# INFO:tensorflow:step = 76101, loss = 0.750728
# INFO:tensorflow:global_step/sec: 40.1918
# INFO:tensorflow:step = 76201, loss = 0.750324
# INFO:tensorflow:global_step/sec: 39.2169
# INFO:tensorflow:step = 76301, loss = 0.749934
# INFO:tensorflow:global_step/sec: 36.4996
# INFO:tensorflow:step = 76401, loss = 0.749561
# INFO:tensorflow:Saving checkpoints for 76500 into ./temp_log_900_9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.749201.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_0', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_1', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_2', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_3', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_4', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_5', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_6', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_0', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_1', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_2', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_3', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_4', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# 2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:322: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_summary_steps': 100, '_task_id': 0, '_master': '', '_keep_checkpoint_every_n_hours': 10000, '_keep_checkpoint_max': 5, '_tf_random_seed': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_task_type': None, '_is_chief': True, '_environment': 'local', '_num_ps_replicas': 0, '_evaluation_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x00000216662707F0>, '_save_checkpoints_secs': 600, '_save_checkpoints_steps': None}
# DEBUG:tensorflow:Setting feature info to {'reflectance_6': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(70560)]), is_sparse=False), 'solar_1': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(70560)]), is_sparse=False), 'reflectance_2': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(70560)]), is_sparse=False), 'solar_0': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(70560)]), is_sparse=False), 'reflectance_4': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(70560)]), is_sparse=False), 'reflectance_3': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(70560)]), is_sparse=False), 'reflectance_1': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(70560)]), is_sparse=False), 'solar_2': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(70560)]), is_sparse=False), 'solar_4': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(70560)]), is_sparse=False), 'reflectance_0': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(70560)]), is_sparse=False), 'solar_3': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(70560)]), is_sparse=False), 'reflectance_5': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(70560)]), is_sparse=False)}.
# DEBUG:tensorflow:Setting labels info to TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(70560)]), is_sparse=False)
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_0', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_1', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_2', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_3', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_4', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_5', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_6', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_0', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_1', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_2', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_3', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_4', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 76501 into ./temp_log_900_9\model.ckpt.
# INFO:tensorflow:step = 76501, loss = 0.717726
# INFO:tensorflow:global_step/sec: 36.5877
# INFO:tensorflow:step = 76601, loss = 0.71638
# INFO:tensorflow:global_step/sec: 40.127
# INFO:tensorflow:step = 76701, loss = 0.715653
# INFO:tensorflow:global_step/sec: 43.5066
# INFO:tensorflow:step = 76801, loss = 0.715033
# INFO:tensorflow:global_step/sec: 42.0344
# INFO:tensorflow:step = 76901, loss = 0.714487
# INFO:tensorflow:global_step/sec: 35.3307
# INFO:tensorflow:step = 77001, loss = 0.714003
# INFO:tensorflow:global_step/sec: 41.7222
# INFO:tensorflow:step = 77101, loss = 0.713567
# INFO:tensorflow:global_step/sec: 43.5157
# INFO:tensorflow:step = 77201, loss = 0.713174
# INFO:tensorflow:global_step/sec: 39.9796
# INFO:tensorflow:step = 77301, loss = 0.712818
# INFO:tensorflow:Saving checkpoints for 77400 into ./temp_log_900_9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.712498.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_0', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_1', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_2', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_3', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_4', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_5', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_6', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_0', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_1', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_2', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_3', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_4', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# 0.790080157144
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:322: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_summary_steps': 100, '_task_id': 0, '_master': '', '_keep_checkpoint_every_n_hours': 10000, '_keep_checkpoint_max': 5, '_tf_random_seed': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_task_type': None, '_is_chief': True, '_environment': 'local', '_num_ps_replicas': 0, '_evaluation_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000021664FD7E80>, '_save_checkpoints_secs': 600, '_save_checkpoints_steps': None}
# DEBUG:tensorflow:Setting feature info to {'reflectance_6': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(66640)]), is_sparse=False), 'solar_1': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(66640)]), is_sparse=False), 'reflectance_2': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(66640)]), is_sparse=False), 'solar_0': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(66640)]), is_sparse=False), 'reflectance_4': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(66640)]), is_sparse=False), 'reflectance_3': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(66640)]), is_sparse=False), 'reflectance_1': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(66640)]), is_sparse=False), 'solar_2': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(66640)]), is_sparse=False), 'solar_4': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(66640)]), is_sparse=False), 'reflectance_0': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(66640)]), is_sparse=False), 'solar_3': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(66640)]), is_sparse=False), 'reflectance_5': TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(66640)]), is_sparse=False)}.
# DEBUG:tensorflow:Setting labels info to TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(66640)]), is_sparse=False)
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_0', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_1', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_2', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_3', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_4', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_5', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_6', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_0', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_1', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_2', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_3', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_4', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 77401 into ./temp_log_900_9\model.ckpt.
# INFO:tensorflow:step = 77401, loss = 0.690878
# INFO:tensorflow:global_step/sec: 39.8384
# INFO:tensorflow:step = 77501, loss = 0.689589
# INFO:tensorflow:global_step/sec: 41.9162
# INFO:tensorflow:step = 77601, loss = 0.688613
# INFO:tensorflow:global_step/sec: 43.4543
# INFO:tensorflow:step = 77701, loss = 0.687754
# INFO:tensorflow:global_step/sec: 43.6759
# INFO:tensorflow:step = 77801, loss = 0.686989
# INFO:tensorflow:global_step/sec: 42.9413
# INFO:tensorflow:step = 77901, loss = 0.686309
# INFO:tensorflow:global_step/sec: 47.3341
# INFO:tensorflow:step = 78001, loss = 0.685701
# INFO:tensorflow:global_step/sec: 39.3424
# INFO:tensorflow:step = 78101, loss = 0.68516
# INFO:tensorflow:global_step/sec: 40.7082
# INFO:tensorflow:step = 78201, loss = 0.684674
# INFO:tensorflow:Saving checkpoints for 78300 into ./temp_log_900_9\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.684242.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_0', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_1', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_2', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_3', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_4', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# ...
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_2', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_3', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_4', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_5', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='reflectance_6', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_0', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_1', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_2', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_3', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# DEBUG:tensorflow:Transforming feature_column _RealValuedColumn(column_name='solar_4', dimension=1, default_value=None, dtype=tf.float32, normalizer=None)
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:1362: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-491f387ea202> in <module>()
#      92                                                   model_dir=model_dir)
#      93
# ---> 94         model_dnn.fit(input_fn=lambda: input_fn(train_fold), steps=steps)
#      95
#      96         models = {"dnn": model_dnn}
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     278             _call_location(), decorator_utils.get_qualified_name(func),
#     279             func.__module__, arg_name, date, instructions)
# --> 280       return func(*args, **kwargs)
#     281     new_func.__doc__ = _add_deprecated_arg_notice_to_docstring(
#     282         func.__doc__, date, instructions)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\estimator.py in fit(self, x, y, input_fn, steps, batch_size, monitors, max_steps)
#     424       hooks.append(basic_session_run_hooks.StopAtStepHook(steps, max_steps))
#     425
# --> 426     loss = self._train_model(input_fn=input_fn, hooks=hooks)
#     427     logging.info('Loss for final step: %s.', loss)
#     428     return self
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\estimator.py in _train_model(self, input_fn, hooks)
#     982         loss = None
#     983         while not mon_sess.should_stop():
# --> 984           _, loss = mon_sess.run([model_fn_ops.train_op, model_fn_ops.loss])
#     985       summary_io.SummaryWriterCache.clear()
#     986       return loss
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     460                           feed_dict=feed_dict,
#     461                           options=options,
# --> 462                           run_metadata=run_metadata)
#     463
#     464   def should_stop(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     784                               feed_dict=feed_dict,
#     785                               options=options,
# --> 786                               run_metadata=run_metadata)
#     787       except errors.AbortedError:
#     788         logging.info('An AbortedError was raised. Closing the current session. '
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\monitored_session.py in run(self, *args, **kwargs)
#     742
#     743   def run(self, *args, **kwargs):
# --> 744     return self._sess.run(*args, **kwargs)
#     745
#     746
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     881     options = options or config_pb2.RunOptions()
#     882     feed_dict = self._call_hook_before_run(run_context, actual_fetches,
# --> 883                                            feed_dict, options)
#     884
#     885     # Do session run.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\monitored_session.py in _call_hook_before_run(self, run_context, fetch_dict, user_feed_dict, options)
#     907     hook_feeds = {}
#     908     for hook in self._hooks:
# --> 909       request = hook.before_run(run_context)
#     910       if request is not None:
#     911         if request.fetches is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\basic_session_run_hooks.py in before_run(self, run_context)
#     338           ops.get_default_graph().as_graph_def(add_shapes=True),
#     339           self._checkpoint_dir,
# --> 340           "graph.pbtxt")
#     341       saver_def = self._get_saver().saver_def if self._get_saver() else None
#     342       graph = ops.get_default_graph()
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\graph_io.py in write_graph(graph_or_graph_def, logdir, name, as_text)
#      65   path = os.path.join(logdir, name)
#      66   if as_text:
# ---> 67     file_io.atomic_write_string_to_file(path, str(graph_def))
#      68   else:
#      69     file_io.atomic_write_string_to_file(path, graph_def.SerializeToString())
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\internal\python_message.py in __str__(self)
#     962   """Helper for _AddMessageMethods()."""
#     963   def __str__(self):
# --> 964     return text_format.MessageToString(self)
#     965   cls.__str__ = __str__
#     966
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in MessageToString(message, as_utf8, as_one_line, pointy_brackets, use_index_order, float_format, use_field_number, descriptor_pool, indent)
#     157                      use_index_order, float_format, use_field_number,
#     158                      descriptor_pool)
# --> 159   printer.PrintMessage(message)
#     160   result = out.getvalue()
#     161   out.close()
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in PrintMessage(self, message)
#     322       elif field.label == descriptor.FieldDescriptor.LABEL_REPEATED:
#     323         for element in value:
# --> 324           self.PrintField(field, element)
#     325       else:
#     326         self.PrintField(field, value)
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in PrintField(self, field, value)
#     353       out.write(': ')
#     354
# --> 355     self.PrintFieldValue(field, value)
#     356     if self.as_one_line:
#     357       out.write(' ')
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in PrintFieldValue(self, field, value)
#     389     out = self.out
#     390     if field.cpp_type == descriptor.FieldDescriptor.CPPTYPE_MESSAGE:
# --> 391       self._PrintMessageFieldValue(value)
#     392     elif field.cpp_type == descriptor.FieldDescriptor.CPPTYPE_ENUM:
#     393       enum_value = field.enum_type.values_by_number.get(value, None)
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in _PrintMessageFieldValue(self, value)
#     374       self.out.write(' %s\n' % openb)
#     375       self.indent += 2
# --> 376       self.PrintMessage(value)
#     377       self.indent -= 2
#     378       self.out.write(' ' * self.indent + closeb)
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in PrintMessage(self, message)
#     319           # TODO(haberman): refactor and optimize if this becomes an issue.
#     320           entry_submsg = value.GetEntryClass()(key=key, value=value[key])
# --> 321           self.PrintField(field, entry_submsg)
#     322       elif field.label == descriptor.FieldDescriptor.LABEL_REPEATED:
#     323         for element in value:
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in PrintField(self, field, value)
#     353       out.write(': ')
#     354
# --> 355     self.PrintFieldValue(field, value)
#     356     if self.as_one_line:
#     357       out.write(' ')
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in PrintFieldValue(self, field, value)
#     389     out = self.out
#     390     if field.cpp_type == descriptor.FieldDescriptor.CPPTYPE_MESSAGE:
# --> 391       self._PrintMessageFieldValue(value)
#     392     elif field.cpp_type == descriptor.FieldDescriptor.CPPTYPE_ENUM:
#     393       enum_value = field.enum_type.values_by_number.get(value, None)
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in _PrintMessageFieldValue(self, value)
#     374       self.out.write(' %s\n' % openb)
#     375       self.indent += 2
# --> 376       self.PrintMessage(value)
#     377       self.indent -= 2
#     378       self.out.write(' ' * self.indent + closeb)
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in PrintMessage(self, message)
#     324           self.PrintField(field, element)
#     325       else:
# --> 326         self.PrintField(field, value)
#     327
#     328   def PrintField(self, field, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in PrintField(self, field, value)
#     353       out.write(': ')
#     354
# --> 355     self.PrintFieldValue(field, value)
#     356     if self.as_one_line:
#     357       out.write(' ')
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in PrintFieldValue(self, field, value)
#     389     out = self.out
#     390     if field.cpp_type == descriptor.FieldDescriptor.CPPTYPE_MESSAGE:
# --> 391       self._PrintMessageFieldValue(value)
#     392     elif field.cpp_type == descriptor.FieldDescriptor.CPPTYPE_ENUM:
#     393       enum_value = field.enum_type.values_by_number.get(value, None)
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in _PrintMessageFieldValue(self, value)
#     374       self.out.write(' %s\n' % openb)
#     375       self.indent += 2
# --> 376       self.PrintMessage(value)
#     377       self.indent -= 2
#     378       self.out.write(' ' * self.indent + closeb)
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in PrintMessage(self, message)
#     324           self.PrintField(field, element)
#     325       else:
# --> 326         self.PrintField(field, value)
#     327
#     328   def PrintField(self, field, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in PrintField(self, field, value)
#     353       out.write(': ')
#     354
# --> 355     self.PrintFieldValue(field, value)
#     356     if self.as_one_line:
#     357       out.write(' ')
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in PrintFieldValue(self, field, value)
#     389     out = self.out
#     390     if field.cpp_type == descriptor.FieldDescriptor.CPPTYPE_MESSAGE:
# --> 391       self._PrintMessageFieldValue(value)
#     392     elif field.cpp_type == descriptor.FieldDescriptor.CPPTYPE_ENUM:
#     393       enum_value = field.enum_type.values_by_number.get(value, None)
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in _PrintMessageFieldValue(self, value)
#     374       self.out.write(' %s\n' % openb)
#     375       self.indent += 2
# --> 376       self.PrintMessage(value)
#     377       self.indent -= 2
#     378       self.out.write(' ' * self.indent + closeb)
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in PrintMessage(self, message)
#     324           self.PrintField(field, element)
#     325       else:
# --> 326         self.PrintField(field, value)
#     327
#     328   def PrintField(self, field, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in PrintField(self, field, value)
#     353       out.write(': ')
#     354
# --> 355     self.PrintFieldValue(field, value)
#     356     if self.as_one_line:
#     357       out.write(' ')
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_format.py in PrintFieldValue(self, field, value)
#     407       else:
#     408         out_as_utf8 = self.as_utf8
# --> 409       out.write(text_encoding.CEscape(out_value, out_as_utf8))
#     410       out.write('\"')
#     411     elif field.cpp_type == descriptor.FieldDescriptor.CPPTYPE_BOOL:
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_encoding.py in CEscape(text, as_utf8)
#      77   if as_utf8:
#      78     return ''.join(_cescape_utf8_to_str[Ord(c)] for c in text)
# ---> 79   return ''.join(_cescape_byte_to_str[Ord(c)] for c in text)
#      80
#      81
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\protobuf\text_encoding.py in <genexpr>(.0)
#      77   if as_utf8:
#      78     return ''.join(_cescape_utf8_to_str[Ord(c)] for c in text)
# ---> 79   return ''.join(_cescape_byte_to_str[Ord(c)] for c in text)
#      80
#      81
#
# KeyboardInterrupt:
